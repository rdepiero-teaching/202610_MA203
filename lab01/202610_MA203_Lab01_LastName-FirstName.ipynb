# %% [markdown]
# # Lab 1 Assignment
#
# Your graded assignment for this lab is to go through Worksheet 0 and find the solution to each problem using sympy. All problem types may not have been covered in the demo given in class. Try searching the documentation first to see if you can find how to do something (Google searches help in this as well). If you still can't find your answer, please contact me.
#
# **Instructions for Completion**
#
# * Enter your code in the coresponding labelled section for each problem in this notebook.
# * Save the notebook and rename with your last name and first name.
# * Upload the assignment to Moodle
#
# This assignment will be graded for completion only and is worth 40 points. This grade will fall under the Written Homework and Projects portion of your course grade.
#
# _Try typing in the problem in the markdown cell for each problem_ All inline math text goes inside `$ $` and anything you want centered on it's own line in `$$ $$`. Use the markdown cells in the class demo to help you out.
#
# ### Import libraries

# %%
from sympy import *
init_printing()  #this prints things in a 'pretty' way with usual math notation

# %% [markdown]
# ### Problem 1
# Simplify the following as much as possible

# %% [markdown]
# #### (a) $\quad \displaystyle \frac{\frac{1}{4} - \frac{2}{3}}{\frac{3}{2} - \frac{2}{3}}$

# %% [markdown]
# #### (b)  $\quad \displaystyle \frac{3}{4}\left(\frac{1}{2} - \frac{1}{3} \right)$

# %% [markdown]
# #### (c) $\quad \displaystyle \left(\frac{-1}{27}\right)^{\frac{4}{3}}$

# %% [markdown]
# #### (d) $\quad\sqrt{75}$

# %% [markdown]
# ### Problem 2
#
# Use the unit circle to find the following.

# %% [markdown]
# #### (a) $\quad\sin\left(\frac{\pi}{6}\right)$

# %% [markdown]
# #### (b) $\quad\cos\left(\frac{\pi}{6}\right)$

# %% [markdown]
# #### (c) $\quad\tan\left(\frac{\pi}{6}\right)$

# %% [markdown]
# #### (c) $\quad \arctan\left(-\sqrt{3}\right)$

# %% [markdown]
# ### Problem 3
#
# Convert $-\frac{5\pi}{6}$ to degrees. Round your result to two decimal places.

# %% [markdown]
# ### Problem 4
# Convert $27^{\circ}$ to radians. Exact answers only.

# %% [markdown]
# ### Problem 5
# Solve the equation $$2x^2 - 3x + 1 = 0$$

# %% [markdown]
# ### Problem 6
#
# Solve the system of equations
# $$\begin{array}{c}
# 	3x + y = 13 \\
# 	x + 6y = -7
#     \end{array} $$

# %% [markdown]
# ### Problem 7
#
# Solve the equation $$e^{x^2+2x-3} = 1$$

# %% [markdown]
# ### Problem 8
#
# Evaluate the following limits.

# %% [markdown]
# #### (a) $\quad\displaystyle\lim_{t\to -2} \frac{t^4-2}{2t^2-3t+2}$

# %% [markdown]
# #### (b) $\quad\displaystyle\lim_{h\to 0} \frac{\sqrt{9+h}-3}{h}$

# %% [markdown]
# ### Problem 9
#
# Evaluate the following limits.

# %% [markdown]
# #### (a) $\quad\displaystyle\lim_{x\to 3} \frac{x^2 - 2x -3}{x-3}$

# %% [markdown]
# #### (b) $\quad\displaystyle\lim_{x\to \infty} \frac{x^3}{x+2}$

# %% [markdown]
# ### Problem 10
# Differentiate $$f(t) = \sqrt{t}\Big(\sqrt{t} + 1\Big)$$

# %% [markdown]
# ### Problem 11
# Differentiate $$y = (x^2+1)^4$$

# %% [markdown]
# ### Problem 12
#
# Differentiate $$ y = \frac{x}{x^2 + 1}$$

# %% [markdown]
# ### Problem 13
# Evaluate the following integrals.

# %% [markdown]
# #### (a) $\quad \displaystyle\int \left(\frac{6}{\sqrt{x}}+ 6\sqrt{x}\right)\,dx$

# %% [markdown]
# #### (b) $\quad \displaystyle\int_{0}^{\ln{8}} e^x\,dx$

# %% [markdown]
# #### (c) $\quad \displaystyle \int_{0}^{\pi/4} 2\cos{x}\,dx$

# %% [markdown]
# ### Problem 14
# Use the second derivative test to determine the maximum and minimum value(s) of the function $h(t) = 6t^2 - t^3$.
#
# *Note: this problem will need to be done in multiple steps!*
